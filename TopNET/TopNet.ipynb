# %% [markdown]
# # 3D vascular segmentation of the liver with TOPNET
#
# And easily use below features:
# 1. Transforms for dictionary format data.
# 1. Load Nifti image with metadata.
# 1. Add channel dim to the data if no channel dimension.
# 1. Scale medical image intensity with expected range.
# 1. Crop out a batch of balanced images based on positive / negative label ratio.
# 1. Cache IO and transforms to accelerate training and validation.
# 1. TopNet model, Dice loss function, Mean Dice metric for 3D segmentation task.
# 1. Sliding window inference method.
# 1. Deterministic training for reproducibility.

# %% [markdown]
# ## Setup environment

# %%
# !python -c "import monai" || pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]"
# !python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/monai/__init__.py", line 40, in <module>
#     from .utils.module import load_submodules  # noqa: E402
#   File "/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/monai/utils/__init__.py", line 17, in <module>
#     from .deprecate_utils import DeprecatedError, deprecated, deprecated_arg, deprecated_arg_default
#   File "/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/monai/utils/deprecate_utils.py", line 22, in <module>
#     from monai.utils.module import version_leq
#   File "/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/monai/utils/module.py", line 30, in <module>
#     import torch
#   File "/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# ImportError: dlopen(/Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so, 2): Library not loaded: @rpath/libtorch_cpu.dylib
#   Referenced from: /Users/divyaurquijo/opt/miniconda3/lib/python3.9/site-packages/torch/lib/libtorch_python.dylib
#   Reason: image not found
# Traceback (most recent call last):
#   File "/usr/local/bin/pip", line 9, in <module>
#     load_entry_point('pip==21.0.1', 'console_scripts', 'pip')()
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/pkg_resources/__init__.py", line 489, in load_entry_point
#     return get_distribution(dist).load_entry_point(group, name)
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/pkg_resources/__init__.py", line 2843, in load_entry_point
#     return ep.load()
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/pkg_resources/__init__.py", line 2434, in load
#     return self.resolve()
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/pkg_resources/__init__.py", line 2440, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#   File "/Library/Python/2.7/site-packages/pip-21.0.1-py2.7.egg/pip/_internal/cli/main.py", line 60
#     sys.stderr.write(f"ERROR: {exc}")
#                                    ^
# SyntaxError: invalid syntax
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/divyaurquijo/Desktop/Contraintes-topologiques-pour-la-segmentation-vasculaire-par-apprentissage-profond-/TopNET/TopNet.ipynb Cellule 3 line 3
#       <a href='vscode-notebook-cell:/Users/divyaurquijo/Desktop/Contraintes-topologiques-pour-la-segmentation-vasculaire-par-apprentissage-profond-/TopNET/TopNet.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().system('python -c "import monai" || pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]"')
#       <a href='vscode-notebook-cell:/Users/divyaurquijo/Desktop/Contraintes-topologiques-pour-la-segmentation-vasculaire-par-apprentissage-profond-/TopNET/TopNet.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().system('python -c "import matplotlib" || pip install -q matplotlib')
# ----> <a href='vscode-notebook-cell:/Users/divyaurquijo/Desktop/Contraintes-topologiques-pour-la-segmentation-vasculaire-par-apprentissage-profond-/TopNET/TopNet.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2454, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2452     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2453 with self.builtin_trap:
# -> 2454     result = fn(*args, **kwargs)
#    2456 # The code below prevents the output from being displayed
#    2457 # when using magics with decorator @output_can_be_silenced
#    2458 # when the last Python token in the expression is a ';'.
#    2459 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3628, in InteractiveShell.enable_matplotlib(self, gui)
#    3607 def enable_matplotlib(self, gui=None):
#    3608     """Enable interactive matplotlib and inline figure support.
#    3609
#    3610     This takes the following steps:
#    (...)
#    3626         display figures inline.
#    3627     """
# -> 3628     from matplotlib_inline.backend_inline import configure_inline_support
#    3630     from IPython.core import pylabtools as pt
#    3631     gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib_inline/__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib_inline/backend_inline.py:6
#       1 """A matplotlib backend for publishing figures via display_data"""
#       3 # Copyright (c) IPython Development Team.
#       4 # Distributed under the terms of the BSD 3-Clause License.
# ----> 6 import matplotlib
#       7 from matplotlib import colors
#       8 from matplotlib.backends import backend_agg
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Setup imports

# %%
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
from TopNet_model import *

print_config()
# Out:
# MONAI version: 1.4.dev2343
# Numpy version: 1.23.5
# Pytorch version: 2.1.0+cu118
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a5f99d230079f8307a3244065ee71551ce373525
# MONAI __file__: /usr/local/lib/python3.10/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.11
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 4.0.2
# scikit-image version: 0.19.3
# scipy version: 1.11.3
# Pillow version: 9.4.0
# Tensorboard version: 2.14.1
# gdown version: 4.6.6
# TorchVision version: 0.16.0+cu118
# tqdm version: 4.66.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## Setup data directory
#
# You can specify a directory with the `MONAI_DATA_DIRECTORY` environment variable.
# This allows you to save results and reuse downloads.
# If not specified a temporary directory will be used.

# %%
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmpg1ie0j4c

# %% [markdown]
# ## Set MSD Spleen dataset path

# %%
train_images = sorted(glob.glob(os.path.join("*VE.nii.gz")))
train_labels = sorted(glob.glob(os.path.join("*VE-por.nii.gz")))
data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]
train_files, val_files = data_dicts[:-5], data_dicts[-4:]
print(train_files, val_files)
# Out:
# [{'image': '01-VE.nii.gz', 'label': '01-VE-por.nii.gz'}, {'image': '02-VE.nii.gz', 'label': '02-VE-por.nii.gz'}, {'image': '03-VE.nii.gz', 'label': '03-VE-por.nii.gz'}, {'image': '04-VE.nii.gz', 'label': '04-VE-por.nii.gz'}, {'image': '05-VE.nii.gz', 'label': '05-VE-por.nii.gz'}, {'image': '06-VE.nii.gz', 'label': '06-VE-por.nii.gz'}, {'image': '07-VE.nii.gz', 'label': '07-VE-por.nii.gz'}, {'image': '08-VE.nii.gz', 'label': '08-VE-por.nii.gz'}, {'image': '09-VE.nii.gz', 'label': '09-VE-por.nii.gz'}, {'image': '10-VE.nii.gz', 'label': '10-VE-por.nii.gz'}, {'image': '11-VE.nii.gz', 'label': '11-VE-por.nii.gz'}, {'image': '12-VE.nii.gz', 'label': '12-VE-por.nii.gz'}, {'image': '13-VE.nii.gz', 'label': '13-VE-por.nii.gz'}, {'image': '14-VE.nii.gz', 'label': '14-VE-por.nii.gz'}, {'image': '15-VE.nii.gz', 'label': '15-VE-por.nii.gz'}] [{'image': '17-VE.nii.gz', 'label': '17-VE-por.nii.gz'}, {'image': '18-VE.nii.gz', 'label': '18-VE-por.nii.gz'}, {'image': '19-VE.nii.gz', 'label': '19-VE-por.nii.gz'}, {'image': '20-VE.nii.gz', 'label': '20-VE-por.nii.gz'}]

# %% [markdown]
# ## Set deterministic training for reproducibility

# %%
set_determinism(seed=0)

# %% [markdown]
# ## Setup transforms for training and validation
#
# Here we use several transforms to augment the dataset:
# 1. `LoadImaged` loads the spleen CT images and labels from NIfTI format files.
# 1. `EnsureChannelFirstd` ensures the original data to construct "channel first" shape.
# 1. `Orientationd` unifies the data orientation based on the affine matrix.
# 1. `Spacingd` adjusts the spacing by `pixdim=(1.5, 1.5, 2.)` based on the affine matrix.
# 1. `ScaleIntensityRanged` extracts intensity range [-57, 164] and scales to [0, 1].
# 1. `CropForegroundd` removes all zero borders to focus on the valid body area of the images and labels.
# 1. `RandCropByPosNegLabeld` randomly crop patch samples from big image based on pos / neg ratio.
# The image centers of negative samples must be in valid body area.
# 1. `RandAffined` efficiently performs `rotate`, `scale`, `shear`, `translate`, etc. together based on PyTorch affine transform.

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(96, 96, 96),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        # user can also add other random transforms
        # RandAffined(
        #     keys=['image', 'label'],
        #     mode=('bilinear', 'nearest'),
        #     prob=1.0, spatial_size=(96, 96, 96),
        #     rotate_range=(0, 0, np.pi/15),
        #     scale_range=(0.1, 0.1, 0.1)),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    ]
)

# %% [markdown]
# ## Check transforms in DataLoader

# %%
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")
# plot the slice [:, :, 80]
plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(image[:, :, 80], cmap="gray")
plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(label[:, :, 80])
plt.show()
# Out:
# image shape: torch.Size([127, 127, 103]), label shape: torch.Size([127, 127, 103])

# %% [markdown]
# ## Define CacheDataset and DataLoader for training and validation
#
# Here we use CacheDataset to accelerate training and validation process, it's 10x faster than the regular Dataset.
# To achieve best performance, set `cache_rate=1.0` to cache all the data, if memory is not enough, set lower value.
# Users can also set `cache_num` instead of `cache_rate`, will use the minimum value of the 2 settings.
# And set `num_workers` to enable multi-threads during caching.
# If want to to try the regular Dataset, just change to use the commented code below.

# %%
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4)
# train_ds = Dataset(data=train_files, transform=train_transforms)

# use batch_size=2 to load images and use RandCropByPosNegLabeld
# to generate 2 x 4 images for network training
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
# val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)
# Out:
# Loading dataset: 100%|██████████| 15/15 [00:13<00:00,  1.14it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Loading dataset: 100%|██████████| 4/4 [00:03<00:00,  1.10it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ## Create Model, Loss, Optimizer

# %%
# standard PyTorch program style: create UNet, DiceLoss and Adam optimizer
device = torch.device("cuda:0")
model = TopNet(n_channels=3, n_classes=2).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %% [markdown]
# ## Execute a typical PyTorch training process

# %%
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                roi_size = (160, 160, 160)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(root_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
# Out:
# ----------
# epoch 1/100
# 1/7, train_loss: 0.6843
# 2/7, train_loss: 0.6840
# 3/7, train_loss: 0.6825
# 4/7, train_loss: 0.6818
# 5/7, train_loss: 0.6796
# 6/7, train_loss: 0.6774
# 7/7, train_loss: 0.6681
# 8/7, train_loss: 0.6780
# epoch 1 average loss: 0.6795
# ----------
# epoch 2/100
# 1/7, train_loss: 0.6758
# 2/7, train_loss: 0.6721
# 3/7, train_loss: 0.6729
# 4/7, train_loss: 0.6681
# 5/7, train_loss: 0.6682
# 6/7, train_loss: 0.6638
# 7/7, train_loss: 0.6582
# 8/7, train_loss: 0.6606
# epoch 2 average loss: 0.6675
# saved new best metric model
# current epoch: 2 current mean dice: 0.0142
# best mean dice: 0.0142 at epoch: 2
# ----------
# epoch 3/100
# 1/7, train_loss: 0.6638
# 2/7, train_loss: 0.6579
# 3/7, train_loss: 0.6645
# 4/7, train_loss: 0.6574
# 5/7, train_loss: 0.6581
# 6/7, train_loss: 0.6552
# 7/7, train_loss: 0.6535
# 8/7, train_loss: 0.6560
# epoch 3 average loss: 0.6583
# ----------
# epoch 4/100
# 1/7, train_loss: 0.6508
# 2/7, train_loss: 0.6510
# 3/7, train_loss: 0.6542
# 4/7, train_loss: 0.6518
# 5/7, train_loss: 0.6472
# 6/7, train_loss: 0.6496
# 7/7, train_loss: 0.6531
# 8/7, train_loss: 0.6434
# epoch 4 average loss: 0.6501
# saved new best metric model
# current epoch: 4 current mean dice: 0.0149
# best mean dice: 0.0149 at epoch: 4
# ----------
# epoch 5/100
# 1/7, train_loss: 0.6485
# 2/7, train_loss: 0.6424
# 3/7, train_loss: 0.6453
# 4/7, train_loss: 0.6443
# 5/7, train_loss: 0.6483
# 6/7, train_loss: 0.6430
# 7/7, train_loss: 0.6400
# 8/7, train_loss: 0.6393
# epoch 5 average loss: 0.6439
# ----------
# epoch 6/100
# 1/7, train_loss: 0.6413
# 2/7, train_loss: 0.6363
# 3/7, train_loss: 0.6407
# 4/7, train_loss: 0.6408
# 5/7, train_loss: 0.6347
# 6/7, train_loss: 0.6402
# 7/7, train_loss: 0.6410
# 8/7, train_loss: 0.6383
# epoch 6 average loss: 0.6392
# saved new best metric model
# current epoch: 6 current mean dice: 0.0170
# best mean dice: 0.0170 at epoch: 6
# ----------
# epoch 7/100
# 1/7, train_loss: 0.6399
# 2/7, train_loss: 0.6382
# 3/7, train_loss: 0.6369
# 4/7, train_loss: 0.6359
# 5/7, train_loss: 0.6307
# 6/7, train_loss: 0.6363
# 7/7, train_loss: 0.6342
# 8/7, train_loss: 0.6254
# epoch 7 average loss: 0.6347
# ----------
# epoch 8/100
# 1/7, train_loss: 0.6357
# 2/7, train_loss: 0.6345
# 3/7, train_loss: 0.6339
# 4/7, train_loss: 0.6239
# 5/7, train_loss: 0.6301
# 6/7, train_loss: 0.6316
# 7/7, train_loss: 0.6301
# 8/7, train_loss: 0.6331
# epoch 8 average loss: 0.6316
# saved new best metric model
# current epoch: 8 current mean dice: 0.0183
# best mean dice: 0.0183 at epoch: 8
# ----------
# epoch 9/100
# 1/7, train_loss: 0.6294
# 2/7, train_loss: 0.6261
# 3/7, train_loss: 0.6254
# 4/7, train_loss: 0.6282
# 5/7, train_loss: 0.6277
# 6/7, train_loss: 0.6284
# 7/7, train_loss: 0.6313
# 8/7, train_loss: 0.6302
# epoch 9 average loss: 0.6283
# ----------
# epoch 10/100
# 1/7, train_loss: 0.6225
# 2/7, train_loss: 0.6293
# 3/7, train_loss: 0.6226
# 4/7, train_loss: 0.6236
# 5/7, train_loss: 0.6296
# 6/7, train_loss: 0.6253
# 7/7, train_loss: 0.6263
# 8/7, train_loss: 0.6196
# epoch 10 average loss: 0.6248
# saved new best metric model
# current epoch: 10 current mean dice: 0.0223
# best mean dice: 0.0223 at epoch: 10
# ----------
# epoch 11/100
# 1/7, train_loss: 0.6219
# 2/7, train_loss: 0.6276
# 3/7, train_loss: 0.6216
# 4/7, train_loss: 0.6215
# 5/7, train_loss: 0.6238
# 6/7, train_loss: 0.6221
# 7/7, train_loss: 0.6202
# 8/7, train_loss: 0.6099
# epoch 11 average loss: 0.6211
# ----------
# epoch 12/100
# 1/7, train_loss: 0.6255
# 2/7, train_loss: 0.6201
# 3/7, train_loss: 0.6198
# 4/7, train_loss: 0.6237
# 5/7, train_loss: 0.6144
# 6/7, train_loss: 0.6146
# 7/7, train_loss: 0.6175
# 8/7, train_loss: 0.6059
# epoch 12 average loss: 0.6177
# saved new best metric model
# current epoch: 12 current mean dice: 0.0267
# best mean dice: 0.0267 at epoch: 12
# ----------
# epoch 13/100
# 1/7, train_loss: 0.6174
# 2/7, train_loss: 0.6137
# 3/7, train_loss: 0.6175
# 4/7, train_loss: 0.6188
# 5/7, train_loss: 0.6125
# 6/7, train_loss: 0.6106
# 7/7, train_loss: 0.6155
# 8/7, train_loss: 0.6107
# epoch 13 average loss: 0.6146
# ----------
# epoch 14/100
# 1/7, train_loss: 0.6095
# 2/7, train_loss: 0.6162
# 3/7, train_loss: 0.6127
# 4/7, train_loss: 0.6136
# 5/7, train_loss: 0.6068
# 6/7, train_loss: 0.6159
# 7/7, train_loss: 0.6104
# 8/7, train_loss: 0.6043
# epoch 14 average loss: 0.6112
# saved new best metric model
# current epoch: 14 current mean dice: 0.0313
# best mean dice: 0.0313 at epoch: 14
# ----------
# epoch 15/100
# 1/7, train_loss: 0.6096
# 2/7, train_loss: 0.6183
# 3/7, train_loss: 0.6087
# 4/7, train_loss: 0.6019
# 5/7, train_loss: 0.6090
# 6/7, train_loss: 0.6068
# 7/7, train_loss: 0.6125
# 8/7, train_loss: 0.6016
# epoch 15 average loss: 0.6086
# ----------
# epoch 16/100
# 1/7, train_loss: 0.6133
# 2/7, train_loss: 0.5994
# 3/7, train_loss: 0.6032
# 4/7, train_loss: 0.6015
# 5/7, train_loss: 0.6084
# 6/7, train_loss: 0.6025
# 7/7, train_loss: 0.6098
# 8/7, train_loss: 0.6101
# epoch 16 average loss: 0.6060
# saved new best metric model
# current epoch: 16 current mean dice: 0.0313
# best mean dice: 0.0313 at epoch: 16
# ----------
# epoch 17/100
# 1/7, train_loss: 0.6048
# 2/7, train_loss: 0.6102
# 3/7, train_loss: 0.6071
# 4/7, train_loss: 0.6061
# 5/7, train_loss: 0.5955
# 6/7, train_loss: 0.5976
# 7/7, train_loss: 0.5975
# 8/7, train_loss: 0.6069
# epoch 17 average loss: 0.6032
# ----------
# epoch 18/100
# 1/7, train_loss: 0.5965
# 2/7, train_loss: 0.6031
# 3/7, train_loss: 0.6012
# 4/7, train_loss: 0.6024
# 5/7, train_loss: 0.6010
# 6/7, train_loss: 0.5955
# 7/7, train_loss: 0.5997
# 8/7, train_loss: 0.6066
# epoch 18 average loss: 0.6007
# saved new best metric model
# current epoch: 18 current mean dice: 0.0404
# best mean dice: 0.0404 at epoch: 18
# ----------
# epoch 19/100
# 1/7, train_loss: 0.6034
# 2/7, train_loss: 0.5978
# 3/7, train_loss: 0.5961
# 4/7, train_loss: 0.6070
# 5/7, train_loss: 0.5918
# 6/7, train_loss: 0.5898
# 7/7, train_loss: 0.5963
# 8/7, train_loss: 0.5914
# epoch 19 average loss: 0.5967
# ----------
# epoch 20/100
# 1/7, train_loss: 0.5954
# 2/7, train_loss: 0.5991
# 3/7, train_loss: 0.5896
# 4/7, train_loss: 0.6037
# 5/7, train_loss: 0.5994
# 6/7, train_loss: 0.5897
# 7/7, train_loss: 0.5906
# 8/7, train_loss: 0.5845
# epoch 20 average loss: 0.5940
# saved new best metric model
# current epoch: 20 current mean dice: 0.0505
# best mean dice: 0.0505 at epoch: 20
# ----------
# epoch 21/100
# 1/7, train_loss: 0.5964
# 2/7, train_loss: 0.5996
# 3/7, train_loss: 0.5938
# 4/7, train_loss: 0.5981
# 5/7, train_loss: 0.5912
# 6/7, train_loss: 0.5908
# 7/7, train_loss: 0.5786
# 8/7, train_loss: 0.5858
# epoch 21 average loss: 0.5918
# ----------
# epoch 22/100
# 1/7, train_loss: 0.5937
# 2/7, train_loss: 0.5936
# 3/7, train_loss: 0.5851
# 4/7, train_loss: 0.5905
# 5/7, train_loss: 0.6001
# 6/7, train_loss: 0.5832
# 7/7, train_loss: 0.5845
# 8/7, train_loss: 0.5834
# epoch 22 average loss: 0.5893
# saved new best metric model
# current epoch: 22 current mean dice: 0.0687
# best mean dice: 0.0687 at epoch: 22
# ----------
# epoch 23/100
# 1/7, train_loss: 0.5846
# 2/7, train_loss: 0.5904
# 3/7, train_loss: 0.5921
# 4/7, train_loss: 0.5903
# 5/7, train_loss: 0.5900
# 6/7, train_loss: 0.5803
# 7/7, train_loss: 0.5873
# 8/7, train_loss: 0.5724
# epoch 23 average loss: 0.5859
# ----------
# epoch 24/100
# 1/7, train_loss: 0.5803
# 2/7, train_loss: 0.5823
# 3/7, train_loss: 0.5823
# 4/7, train_loss: 0.5811
# 5/7, train_loss: 0.5910
# 6/7, train_loss: 0.5890
# 7/7, train_loss: 0.5826
# 8/7, train_loss: 0.5845
# epoch 24 average loss: 0.5841
# current epoch: 24 current mean dice: 0.0510
# best mean dice: 0.0687 at epoch: 22
# ----------
# epoch 25/100
# 1/7, train_loss: 0.5800
# 2/7, train_loss: 0.5828
# 3/7, train_loss: 0.5855
# 4/7, train_loss: 0.5718
# 5/7, train_loss: 0.5869
# 6/7, train_loss: 0.5718
# 7/7, train_loss: 0.5801
# 8/7, train_loss: 0.5957
# epoch 25 average loss: 0.5818
# ----------
# epoch 26/100
# 1/7, train_loss: 0.5725
# 2/7, train_loss: 0.5763
# 3/7, train_loss: 0.5846
# 4/7, train_loss: 0.5845
# 5/7, train_loss: 0.5837
# 6/7, train_loss: 0.5755
# 7/7, train_loss: 0.5757
# 8/7, train_loss: 0.5815
# epoch 26 average loss: 0.5793
# current epoch: 26 current mean dice: 0.0663
# best mean dice: 0.0687 at epoch: 22
# ----------
# epoch 27/100
# 1/7, train_loss: 0.5721
# 2/7, train_loss: 0.5713
# 3/7, train_loss: 0.5824
# 4/7, train_loss: 0.5772
# 5/7, train_loss: 0.5808
# 6/7, train_loss: 0.5814
# 7/7, train_loss: 0.5714
# 8/7, train_loss: 0.5715
# epoch 27 average loss: 0.5760
# ----------
# epoch 28/100
# 1/7, train_loss: 0.5703
# 2/7, train_loss: 0.5733
# 3/7, train_loss: 0.5790
# 4/7, train_loss: 0.5822
# 5/7, train_loss: 0.5701
# 6/7, train_loss: 0.5715
# 7/7, train_loss: 0.5719
# 8/7, train_loss: 0.5697
# epoch 28 average loss: 0.5735
# saved new best metric model
# current epoch: 28 current mean dice: 0.1047
# best mean dice: 0.1047 at epoch: 28
# ----------
# epoch 29/100
# 1/7, train_loss: 0.5682
# 2/7, train_loss: 0.5695
# 3/7, train_loss: 0.5741
# 4/7, train_loss: 0.5610
# 5/7, train_loss: 0.5715
# 6/7, train_loss: 0.5798
# 7/7, train_loss: 0.5717
# 8/7, train_loss: 0.5760
# epoch 29 average loss: 0.5715
# ----------
# epoch 30/100
# 1/7, train_loss: 0.5708
# 2/7, train_loss: 0.5652
# 3/7, train_loss: 0.5687
# 4/7, train_loss: 0.5758
# 5/7, train_loss: 0.5742
# 6/7, train_loss: 0.5689
# 7/7, train_loss: 0.5617
# 8/7, train_loss: 0.5703
# epoch 30 average loss: 0.5694
# saved new best metric model
# current epoch: 30 current mean dice: 0.1154
# best mean dice: 0.1154 at epoch: 30
# ----------
# epoch 31/100
# 1/7, train_loss: 0.5668
# 2/7, train_loss: 0.5791
# 3/7, train_loss: 0.5674
# 4/7, train_loss: 0.5692
# 5/7, train_loss: 0.5680
# 6/7, train_loss: 0.5679
# 7/7, train_loss: 0.5486
# 8/7, train_loss: 0.5621
# epoch 31 average loss: 0.5661
# ----------
# epoch 32/100
# 1/7, train_loss: 0.5602
# 2/7, train_loss: 0.5709
# 3/7, train_loss: 0.5645
# 4/7, train_loss: 0.5518
# 5/7, train_loss: 0.5613
# 6/7, train_loss: 0.5672
# 7/7, train_loss: 0.5701
# 8/7, train_loss: 0.5681
# epoch 32 average loss: 0.5643
# saved new best metric model
# current epoch: 32 current mean dice: 0.1322
# best mean dice: 0.1322 at epoch: 32
# ----------
# epoch 33/100
# 1/7, train_loss: 0.5502
# 2/7, train_loss: 0.5629
# 3/7, train_loss: 0.5678
# 4/7, train_loss: 0.5494
# 5/7, train_loss: 0.5605
# 6/7, train_loss: 0.5650
# 7/7, train_loss: 0.5642
# 8/7, train_loss: 0.5798
# epoch 33 average loss: 0.5625
# ----------
# epoch 34/100
# 1/7, train_loss: 0.5628
# 2/7, train_loss: 0.5537
# 3/7, train_loss: 0.5594
# 4/7, train_loss: 0.5584
# 5/7, train_loss: 0.5538
# 6/7, train_loss: 0.5661
# 7/7, train_loss: 0.5648
# 8/7, train_loss: 0.5518
# epoch 34 average loss: 0.5588
# saved new best metric model
# current epoch: 34 current mean dice: 0.1396
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 35/100
# 1/7, train_loss: 0.5583
# 2/7, train_loss: 0.5603
# 3/7, train_loss: 0.5630
# 4/7, train_loss: 0.5585
# 5/7, train_loss: 0.5459
# 6/7, train_loss: 0.5484
# 7/7, train_loss: 0.5519
# 8/7, train_loss: 0.5758
# epoch 35 average loss: 0.5578
# ----------
# epoch 36/100
# 1/7, train_loss: 0.5532
# 2/7, train_loss: 0.5480
# 3/7, train_loss: 0.5657
# 4/7, train_loss: 0.5647
# 5/7, train_loss: 0.5532
# 6/7, train_loss: 0.5439
# 7/7, train_loss: 0.5552
# 8/7, train_loss: 0.5563
# epoch 36 average loss: 0.5550
# current epoch: 36 current mean dice: 0.1348
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 37/100
# 1/7, train_loss: 0.5578
# 2/7, train_loss: 0.5453
# 3/7, train_loss: 0.5529
# 4/7, train_loss: 0.5480
# 5/7, train_loss: 0.5617
# 6/7, train_loss: 0.5622
# 7/7, train_loss: 0.5428
# 8/7, train_loss: 0.5369
# epoch 37 average loss: 0.5510
# ----------
# epoch 38/100
# 1/7, train_loss: 0.5625
# 2/7, train_loss: 0.5506
# 3/7, train_loss: 0.5490
# 4/7, train_loss: 0.5510
# 5/7, train_loss: 0.5531
# 6/7, train_loss: 0.5410
# 7/7, train_loss: 0.5430
# 8/7, train_loss: 0.5553
# epoch 38 average loss: 0.5507
# current epoch: 38 current mean dice: 0.1362
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 39/100
# 1/7, train_loss: 0.5449
# 2/7, train_loss: 0.5516
# 3/7, train_loss: 0.5456
# 4/7, train_loss: 0.5398
# 5/7, train_loss: 0.5460
# 6/7, train_loss: 0.5416
# 7/7, train_loss: 0.5542
# 8/7, train_loss: 0.5679
# epoch 39 average loss: 0.5490
# ----------
# epoch 40/100
# 1/7, train_loss: 0.5343
# 2/7, train_loss: 0.5439
# 3/7, train_loss: 0.5452
# 4/7, train_loss: 0.5401
# 5/7, train_loss: 0.5538
# 6/7, train_loss: 0.5612
# 7/7, train_loss: 0.5481
# 8/7, train_loss: 0.5373
# epoch 40 average loss: 0.5455
# current epoch: 40 current mean dice: 0.1368
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 41/100
# 1/7, train_loss: 0.5461
# 2/7, train_loss: 0.5469
# 3/7, train_loss: 0.5468
# 4/7, train_loss: 0.5471
# 5/7, train_loss: 0.5354
# 6/7, train_loss: 0.5333
# 7/7, train_loss: 0.5403
# 8/7, train_loss: 0.5547
# epoch 41 average loss: 0.5438
# ----------
# epoch 42/100
# 1/7, train_loss: 0.5438
# 2/7, train_loss: 0.5280
# 3/7, train_loss: 0.5374
# 4/7, train_loss: 0.5358
# 5/7, train_loss: 0.5523
# 6/7, train_loss: 0.5417
# 7/7, train_loss: 0.5420
# 8/7, train_loss: 0.5627
# epoch 42 average loss: 0.5430
# current epoch: 42 current mean dice: 0.1334
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 43/100
# 1/7, train_loss: 0.5411
# 2/7, train_loss: 0.5337
# 3/7, train_loss: 0.5259
# 4/7, train_loss: 0.5451
# 5/7, train_loss: 0.5427
# 6/7, train_loss: 0.5427
# 7/7, train_loss: 0.5447
# 8/7, train_loss: 0.5444
# epoch 43 average loss: 0.5400
# ----------
# epoch 44/100
# 1/7, train_loss: 0.5354
# 2/7, train_loss: 0.5317
# 3/7, train_loss: 0.5397
# 4/7, train_loss: 0.5477
# 5/7, train_loss: 0.5357
# 6/7, train_loss: 0.5320
# 7/7, train_loss: 0.5304
# 8/7, train_loss: 0.5466
# epoch 44 average loss: 0.5374
# current epoch: 44 current mean dice: 0.1177
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 45/100
# 1/7, train_loss: 0.5543
# 2/7, train_loss: 0.5326
# 3/7, train_loss: 0.5340
# 4/7, train_loss: 0.5402
# 5/7, train_loss: 0.5364
# 6/7, train_loss: 0.5147
# 7/7, train_loss: 0.5362
# 8/7, train_loss: 0.5249
# epoch 45 average loss: 0.5342
# ----------
# epoch 46/100
# 1/7, train_loss: 0.5261
# 2/7, train_loss: 0.5258
# 3/7, train_loss: 0.5412
# 4/7, train_loss: 0.5318
# 5/7, train_loss: 0.5245
# 6/7, train_loss: 0.5499
# 7/7, train_loss: 0.5305
# 8/7, train_loss: 0.5283
# epoch 46 average loss: 0.5322
# current epoch: 46 current mean dice: 0.1297
# best mean dice: 0.1396 at epoch: 34
# ----------
# epoch 47/100
# 1/7, train_loss: 0.5376
# 2/7, train_loss: 0.5402
# 3/7, train_loss: 0.5294
# 4/7, train_loss: 0.5333
# 5/7, train_loss: 0.5221
# 6/7, train_loss: 0.5193
# 7/7, train_loss: 0.5394
# 8/7, train_loss: 0.5209
# epoch 47 average loss: 0.5303
# ----------
# epoch 48/100
# 1/7, train_loss: 0.5297
# 2/7, train_loss: 0.5312
# 3/7, train_loss: 0.5066
# 4/7, train_loss: 0.5451
# 5/7, train_loss: 0.5306
# 6/7, train_loss: 0.5285
# 7/7, train_loss: 0.5318
# 8/7, train_loss: 0.5186
# epoch 48 average loss: 0.5277
# saved new best metric model
# current epoch: 48 current mean dice: 0.1491
# best mean dice: 0.1491 at epoch: 48
# ----------
# epoch 49/100
# 1/7, train_loss: 0.5249
# 2/7, train_loss: 0.5133
# 3/7, train_loss: 0.5349
# 4/7, train_loss: 0.5176
# 5/7, train_loss: 0.5344
# 6/7, train_loss: 0.5226
# 7/7, train_loss: 0.5358
# 8/7, train_loss: 0.5344
# epoch 49 average loss: 0.5272
# ----------
# epoch 50/100
# 1/7, train_loss: 0.5237
# 2/7, train_loss: 0.5177
# 3/7, train_loss: 0.5184
# 4/7, train_loss: 0.5187
# 5/7, train_loss: 0.5319
# 6/7, train_loss: 0.5331
# 7/7, train_loss: 0.5233
# 8/7, train_loss: 0.5410
# epoch 50 average loss: 0.5260
# saved new best metric model
# current epoch: 50 current mean dice: 0.1621
# best mean dice: 0.1621 at epoch: 50
# ----------
# epoch 51/100
# 1/7, train_loss: 0.5326
# 2/7, train_loss: 0.5225
# 3/7, train_loss: 0.5309
# 4/7, train_loss: 0.5309
# 5/7, train_loss: 0.5192
# 6/7, train_loss: 0.5039
# 7/7, train_loss: 0.5082
# 8/7, train_loss: 0.5272
# epoch 51 average loss: 0.5219
# ----------
# epoch 52/100
# 1/7, train_loss: 0.5349
# 2/7, train_loss: 0.5049
# 3/7, train_loss: 0.5153
# 4/7, train_loss: 0.5205
# 5/7, train_loss: 0.5333
# 6/7, train_loss: 0.5200
# 7/7, train_loss: 0.5157
# 8/7, train_loss: 0.5124
# epoch 52 average loss: 0.5196
# current epoch: 52 current mean dice: 0.1485
# best mean dice: 0.1621 at epoch: 50
# ----------
# epoch 53/100
# 1/7, train_loss: 0.5255
# 2/7, train_loss: 0.5188
# 3/7, train_loss: 0.5139
# 4/7, train_loss: 0.5246
# 5/7, train_loss: 0.5028
# 6/7, train_loss: 0.5249
# 7/7, train_loss: 0.5098
# 8/7, train_loss: 0.5228
# epoch 53 average loss: 0.5179
# ----------
# epoch 54/100
# 1/7, train_loss: 0.5081
# 2/7, train_loss: 0.5132
# 3/7, train_loss: 0.5318
# 4/7, train_loss: 0.4974
# 5/7, train_loss: 0.5297
# 6/7, train_loss: 0.5218
# 7/7, train_loss: 0.5160
# 8/7, train_loss: 0.4903
# epoch 54 average loss: 0.5135
# current epoch: 54 current mean dice: 0.1469
# best mean dice: 0.1621 at epoch: 50
# ----------
# epoch 55/100
# 1/7, train_loss: 0.5078
# 2/7, train_loss: 0.5171
# 3/7, train_loss: 0.5297
# 4/7, train_loss: 0.5287
# 5/7, train_loss: 0.5152
# 6/7, train_loss: 0.4886
# 7/7, train_loss: 0.5096
# 8/7, train_loss: 0.5208
# epoch 55 average loss: 0.5147
# ----------
# epoch 56/100
# 1/7, train_loss: 0.5110
# 2/7, train_loss: 0.5154
# 3/7, train_loss: 0.4989
# 4/7, train_loss: 0.5165
# 5/7, train_loss: 0.5239
# 6/7, train_loss: 0.5215
# 7/7, train_loss: 0.4914
# 8/7, train_loss: 0.5183
# epoch 56 average loss: 0.5121
# current epoch: 56 current mean dice: 0.1602
# best mean dice: 0.1621 at epoch: 50
# ----------
# epoch 57/100
# 1/7, train_loss: 0.5292
# 2/7, train_loss: 0.4945
# 3/7, train_loss: 0.5064
# 4/7, train_loss: 0.5087
# 5/7, train_loss: 0.5096
# 6/7, train_loss: 0.5140
# 7/7, train_loss: 0.5146
# 8/7, train_loss: 0.5110
# epoch 57 average loss: 0.5110
# ----------
# epoch 58/100
# 1/7, train_loss: 0.5215
# 2/7, train_loss: 0.5243
# 3/7, train_loss: 0.5059
# 4/7, train_loss: 0.5108
# 5/7, train_loss: 0.4954
# 6/7, train_loss: 0.5057
# 7/7, train_loss: 0.5053
# 8/7, train_loss: 0.4800
# epoch 58 average loss: 0.5061
# saved new best metric model
# current epoch: 58 current mean dice: 0.1824
# best mean dice: 0.1824 at epoch: 58
# ----------
# epoch 59/100
# 1/7, train_loss: 0.5308
# 2/7, train_loss: 0.5101
# 3/7, train_loss: 0.4908
# 4/7, train_loss: 0.5068
# 5/7, train_loss: 0.5103
# 6/7, train_loss: 0.5013
# 7/7, train_loss: 0.5086
# 8/7, train_loss: 0.4732
# epoch 59 average loss: 0.5040
# ----------
# epoch 60/100
# 1/7, train_loss: 0.4872
# 2/7, train_loss: 0.4952
# 3/7, train_loss: 0.4959
# 4/7, train_loss: 0.5040
# 5/7, train_loss: 0.5178
# 6/7, train_loss: 0.5006
# 7/7, train_loss: 0.5275
# 8/7, train_loss: 0.5038
# epoch 60 average loss: 0.5040
# current epoch: 60 current mean dice: 0.1401
# best mean dice: 0.1824 at epoch: 58
# ----------
# epoch 61/100
# 1/7, train_loss: 0.5064
# 2/7, train_loss: 0.5179
# 3/7, train_loss: 0.4797
# 4/7, train_loss: 0.5123
# 5/7, train_loss: 0.5076
# 6/7, train_loss: 0.5028
# 7/7, train_loss: 0.4942
# 8/7, train_loss: 0.5053
# epoch 61 average loss: 0.5033
# ----------
# epoch 62/100
# 1/7, train_loss: 0.4874
# 2/7, train_loss: 0.4900
# 3/7, train_loss: 0.5138
# 4/7, train_loss: 0.4971
# 5/7, train_loss: 0.5054
# 6/7, train_loss: 0.5171
# 7/7, train_loss: 0.5012
# 8/7, train_loss: 0.4921
# epoch 62 average loss: 0.5005
# current epoch: 62 current mean dice: 0.1357
# best mean dice: 0.1824 at epoch: 58
# ----------
# epoch 63/100
# epoch 96/100
# 1/7, train_loss: 0.4323
# 2/7, train_loss: 0.4229
# 3/7, train_loss: 0.4662
# 4/7, train_loss: 0.4074
# 5/7, train_loss: 0.4294
# 6/7, train_loss: 0.3946
# 7/7, train_loss: 0.4354
# 8/7, train_loss: 0.4067
# epoch 96 average loss: 0.4244
# current epoch: 96 current mean dice: 0.1679
# best mean dice: 0.1947 at epoch: 78
# ----------
# epoch 97/100
# 1/7, train_loss: 0.4029
# 2/7, train_loss: 0.4445
# 3/7, train_loss: 0.4016
# 4/7, train_loss: 0.4219
# 5/7, train_loss: 0.4011
# 6/7, train_loss: 0.4214
# 7/7, train_loss: 0.4299
# 8/7, train_loss: 0.4832
# epoch 97 average loss: 0.4258
# ----------
# epoch 98/100
# 1/7, train_loss: 0.4209
# 2/7, train_loss: 0.4322
# 3/7, train_loss: 0.4424
# 4/7, train_loss: 0.3988
# 5/7, train_loss: 0.4077
# 6/7, train_loss: 0.4105
# 7/7, train_loss: 0.4424
# 8/7, train_loss: 0.3863
# epoch 98 average loss: 0.4177
# current epoch: 98 current mean dice: 0.1899
# best mean dice: 0.1947 at epoch: 78
# ----------
# epoch 99/100
# 1/7, train_loss: 0.4161
# 2/7, train_loss: 0.4268
# 3/7, train_loss: 0.4104
# 4/7, train_loss: 0.4228
# 5/7, train_loss: 0.4042
# 6/7, train_loss: 0.4096
# 7/7, train_loss: 0.4227
# 8/7, train_loss: 0.4249
# epoch 99 average loss: 0.4172
# ----------
# epoch 100/100
# 1/7, train_loss: 0.4015
# 2/7, train_loss: 0.3862
# 3/7, train_loss: 0.4084
# 4/7, train_loss: 0.4292
# 5/7, train_loss: 0.4589
# 6/7, train_loss: 0.4206
# 7/7, train_loss: 0.4124
# 8/7, train_loss: 0.3586
# epoch 100 average loss: 0.4095
# saved new best metric model
# current epoch: 100 current mean dice: 0.1990
# best mean dice: 0.1990 at epoch: 100

# %%
print(f"train completed, best_metric: {best_metric:.4f} " f"at epoch: {best_metric_epoch}")
# Out:
# train completed, best_metric: 0.1990 at epoch: 100

# %% [markdown]
# ## Plot the loss and metric

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Check best model output with the input image and label

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
model.eval()
with torch.no_grad():
    for i, val_data in enumerate(val_loader):
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_outputs = sliding_window_inference(val_data["image"].to(device), roi_size, sw_batch_size, model)
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(val_data["image"][0, 0, :, :, 80], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(val_data["label"][0, 0, :, :, 80])
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(torch.argmax(val_outputs, dim=1).detach().cpu()[0, :, :, 80])
        plt.show()
        if i == 2:
            break

# %% [markdown]
# ## Evaluation on original image spacings

# %%
val_org_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        Spacingd(keys=["image"], pixdim=(1.5, 1.5, 2.0), mode="bilinear"),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
    ]
)

val_org_ds = Dataset(data=val_files, transform=val_org_transforms)
val_org_loader = DataLoader(val_org_ds, batch_size=1, num_workers=4)

post_transforms = Compose(
    [
        Invertd(
            keys="pred",
            transform=val_org_transforms,
            orig_keys="image",
            meta_keys="pred_meta_dict",
            orig_meta_keys="image_meta_dict",
            meta_key_postfix="meta_dict",
            nearest_interp=False,
            to_tensor=True,
            device="cpu",
        ),
        AsDiscreted(keys="pred", argmax=True, to_onehot=2),
        AsDiscreted(keys="label", to_onehot=2),
    ]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
model.eval()

with torch.no_grad():
    for val_data in val_org_loader:
        val_inputs = val_data["image"].to(device)
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_data["pred"] = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
        val_data = [post_transforms(i) for i in decollate_batch(val_data)]
        val_outputs, val_labels = from_engine(["pred", "label"])(val_data)
        # compute metric for current iteration
        dice_metric(y_pred=val_outputs, y=val_labels)

    # aggregate the final mean dice result
    metric_org = dice_metric.aggregate().item()
    # reset the status for next validation round
    dice_metric.reset()

print("Metric on original image spacing: ", metric_org)
# Out:
# Metric on original image spacing:  0.20241963863372803

# %% [markdown]
# ## Inference on Test Set

# %%
test_images = sorted(glob.glob(os.path.join("16-VE.nii.gz")))

test_data = [{"image": image} for image in test_images]


test_org_transforms = Compose(
    [
        LoadImaged(keys="image"),
        EnsureChannelFirstd(keys="image"),
        Orientationd(keys=["image"], axcodes="RAS"),
        Spacingd(keys=["image"], pixdim=(1.5, 1.5, 2.0), mode="bilinear"),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
    ]
)

test_org_ds = Dataset(data=test_data, transform=test_org_transforms)

test_org_loader = DataLoader(test_org_ds, batch_size=1, num_workers=4)

post_transforms = Compose(
    [
        Invertd(
            keys="pred",
            transform=test_org_transforms,
            orig_keys="image",
            meta_keys="pred_meta_dict",
            orig_meta_keys="image_meta_dict",
            meta_key_postfix="meta_dict",
            nearest_interp=False,
            to_tensor=True,
        ),
        AsDiscreted(keys="pred", argmax=True, to_onehot=2),
        SaveImaged(keys="pred", meta_keys="pred_meta_dict", output_dir="./out", output_postfix="seg", resample=False),
    ]
)

# %%
# # uncomment the following lines to visualize the predicted results
from monai.transforms import LoadImage
loader = LoadImage()

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
model.eval()

with torch.no_grad():
    for test_data in test_org_loader:
        test_inputs = test_data["image"].to(device)
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        test_data["pred"] = sliding_window_inference(test_inputs, roi_size, sw_batch_size, model)

        test_data = [post_transforms(i) for i in decollate_batch(test_data)]

#         # uncomment the following lines to visualize the predicted results
        test_output = from_engine(["pred"])(test_data)

        original_image = loader(test_output[0].meta["filename_or_obj"])

        plt.figure("check", (18, 6))
        plt.subplot(1, 2, 1)
        plt.imshow(original_image[:, :, 20], cmap="gray")
        plt.subplot(1, 2, 2)
        plt.imshow(test_output[0].detach().cpu()[1, :, :, 20])
        plt.show()
# Out:
# 2023-10-26 18:15:23,631 INFO image_writer.py:197 - writing: out/16-VE/16-VE_seg.nii.gz

# %% [markdown]
# ## Cleanup data directory
#
# Remove directory if a temporary was used.

# %%
#if directory is None:
   # shutil.rmtree(root_dir)
